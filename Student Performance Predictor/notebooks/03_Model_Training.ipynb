# %% [markdown]
# # Step 5: Model Training

# %% [markdown]
# # 5.1 Import Libraries

# %%
# ===============================
# Model Training Libraries
# ===============================

import pandas as pd
import numpy as np

# Train-test split
from sklearn.model_selection import train_test_split

# Preprocessing
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder, StandardScaler

# Regression Models
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import (
    RandomForestRegressor,
    GradientBoostingRegressor,
    ExtraTreesRegressor
)

# Gradient Boosting Libraries
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor

# Evaluation
from sklearn.metrics import (
    mean_absolute_error,
    mean_squared_error,
    r2_score
)

# Save Model
import joblib

# Ignore warnings
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Code Cell 2 — Load the dataset

# %%
# ===============================
# Load Dataset
# ===============================

df = pd.read_csv("../data/raw/Students_Performance.csv")

df.head()
# Out:
#   Student_ID Student_Age     Sex High_School_Type Scholarship Additional_Work  \
# 0   STUDENT1       19-22    Male            Other         50%             Yes
# 1   STUDENT2       19-22    Male            Other         50%             Yes
# 2   STUDENT3       19-22    Male            State         50%              No
# 3   STUDENT4          18  Female          Private         50%             Yes
# 4   STUDENT5       19-22    Male          Private         50%              No
#
#   Sports_activity Transportation  Weekly_Study_Hours Attendance Reading Notes  \
# 0              No        Private                   0     Always     Yes   Yes
# 1              No        Private                   0     Always     Yes    No
# 2              No        Private                   2      Never      No    No
# 3              No            Bus                   2     Always      No   Yes
# 4              No            Bus                  12     Always     Yes    No
#
# ...

# %% [markdown]
# ## Code Cell 3 — Inspect the target

# %%
df["Grade"].value_counts().sort_index()
# Out:
# Grade
# AA      35
# BA      24
# BB      21
# CB      10
# CC      17
# DC      13
# DD      17
# Fail     8
# Name: count, dtype: int64

# %% [markdown]
# ## Code Cell 4 — Convert Grade to numeric

# %%
grade_mapping = {
    "Fail": 0,
    "DD": 1,
    "DC": 2,
    "CC": 3,
    "CB": 4,
    "BB": 5,
    "BA": 6,
    "AA": 7
}

df["Grade"] = df["Grade"].map(grade_mapping)

# %% [markdown]
# ## Code Cell 5 — Verify the conversion

# %%
print(df["Grade"].head())
print(df["Grade"].dtype)
# Out:
# 0    7
# 1    7
# 2    7
# 3    7
# 4    7
# Name: Grade, dtype: int64
# int64

# %% [markdown]
# ## Code Cell 6 — Create X and y

# %%
# ===============================
# Separate Features and Target
# ===============================

X = df.drop("Grade", axis=1)

y = df["Grade"]

# %% [markdown]
# ## Code Cell 7 — Verify the result

# %%
print("Features Shape :", X.shape)
print("Target Shape   :", y.shape)
# Out:
# Features Shape : (145, 14)
# Target Shape   : (145,)

# %% [markdown]
# ## Code Cell 8 — Display Features

# %%
X.head()
# Out:
#   Student_ID Student_Age     Sex High_School_Type Scholarship Additional_Work  \
# 0   STUDENT1       19-22    Male            Other         50%             Yes
# 1   STUDENT2       19-22    Male            Other         50%             Yes
# 2   STUDENT3       19-22    Male            State         50%              No
# 3   STUDENT4          18  Female          Private         50%             Yes
# 4   STUDENT5       19-22    Male          Private         50%              No
#
#   Sports_activity Transportation  Weekly_Study_Hours Attendance Reading Notes  \
# 0              No        Private                   0     Always     Yes   Yes
# 1              No        Private                   0     Always     Yes    No
# 2              No        Private                   2      Never      No    No
# 3              No            Bus                   2     Always      No   Yes
# 4              No            Bus                  12     Always     Yes    No
#
# ...

# %% [markdown]
# ## Code Cell 9 — Display Target

# %%
y.head()
# Out:
# 0    7
# 1    7
# 2    7
# 3    7
# 4    7
# Name: Grade, dtype: int64

# %% [markdown]
# # Step 5.4 — Identify Numerical & Categorical Features

# %% [markdown]
# ## Code Cell 10 — Identify column types

# %%
# ===============================
# Identify Feature Types
# ===============================

numerical_features = X.select_dtypes(
    include=["int64", "float64"]
).columns.tolist()

categorical_features = X.select_dtypes(
    include=["object"]
).columns.tolist()

# %% [markdown]
# ## Code Cell 11 — Display the results

# %%
print("Numerical Features")
print(numerical_features)

print("\nCategorical Features")
print(categorical_features)
# Out:
# Numerical Features
# ['Weekly_Study_Hours']
#
# Categorical Features
# ['Student_ID', 'Student_Age', 'Sex', 'High_School_Type', 'Scholarship', 'Additional_Work', 'Sports_activity', 'Transportation', 'Attendance', 'Reading', 'Notes', 'Listening_in_Class', 'Project_work']

# %% [markdown]
# # Step 5.5 — Build the Preprocessing Pipeline

# %% [markdown]
# ## Code Cell 12 — Numerical Pipeline

# %%
# ===============================
# Numerical Pipeline
# ===============================

numeric_pipeline = Pipeline([
    ("imputer", SimpleImputer(strategy="median")),
    ("scaler", StandardScaler())
])

numeric_pipeline
# Out:
# Pipeline(steps=[('imputer', SimpleImputer(strategy='median')),
#                 ('scaler', StandardScaler())])

# %% [markdown]
# ## Code Cell 13 — Categorical Pipeline

# %%
# ===============================
# Categorical Pipeline
# ===============================

categorical_pipeline = Pipeline([
    ("imputer", SimpleImputer(strategy="most_frequent")),
    ("encoder", OneHotEncoder(handle_unknown="ignore"))
])

categorical_pipeline
# Out:
# Pipeline(steps=[('imputer', SimpleImputer(strategy='most_frequent')),
#                 ('encoder', OneHotEncoder(handle_unknown='ignore'))])

# %% [markdown]
# ## Code Cell 14 — Combine Both Pipelines

# %%
# ===============================
# Full Preprocessor
# ===============================

preprocessor = ColumnTransformer([
    ("num", numeric_pipeline, numerical_features),
    ("cat", categorical_pipeline, categorical_features)
])

preprocessor
# Out:
# ColumnTransformer(transformers=[('num',
#                                  Pipeline(steps=[('imputer',
#                                                   SimpleImputer(strategy='median')),
#                                                  ('scaler', StandardScaler())]),
#                                  ['Weekly_Study_Hours']),
#                                 ('cat',
#                                  Pipeline(steps=[('imputer',
#                                                   SimpleImputer(strategy='most_frequent')),
#                                                  ('encoder',
#                                                   OneHotEncoder(handle_unknown='ignore'))]),
#                                  ['Student_ID', 'Student_Age', 'Sex',
#                                   'High_School_Type', 'Scholarship',
#                                   'Additional_Work', 'Sports_activity',
#                                   'Transportation', 'Attendance', 'Reading',
# ...

# %% [markdown]
# ## Code Cell 15 — Test the Preprocessor

# %%
X_processed = preprocessor.fit_transform(X)

print(type(X_processed))
print(X_processed.shape)
# Out:
# <class 'scipy.sparse._csr.csr_matrix'>
# (145, 178)

# %% [markdown]
# # Step 5.6 — Train/Test Split

# %% [markdown]
# ## Code Cell 16 — Split the Dataset

# %%
# ===============================
# Train-Test Split
# ===============================

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42
)

# %% [markdown]
# ## Code Cell 17 — Verify the Split

# %%
print("X_train:", X_train.shape)
print("X_test :", X_test.shape)
print("y_train:", y_train.shape)
print("y_test :", y_test.shape)
# Out:
# X_train: (116, 14)
# X_test : (29, 14)
# y_train: (116,)
# y_test : (29,)

# %% [markdown]
# ## Code Cell 18 — Check Target Distribution

# %%
print("Training Grade Distribution")
print(y_train.value_counts().sort_index())

print("\nTesting Grade Distribution")
print(y_test.value_counts().sort_index())
# Out:
# Training Grade Distribution
# Grade
# 0     4
# 1    15
# 2     9
# 3    14
# 4     7
# 5    15
# 6    20
# 7    32
# Name: count, dtype: int64
#
# Testing Grade Distribution
# Grade
# 0    4
# 1    2
# 2    4
# 3    3
# 4    3
# 5    6
# 6    4
# 7    3
# Name: count, dtype: int64

# %% [markdown]
# # Step 5.7 — Train 8 Regression Models (Professional)

# %% [markdown]
# ## 5.7.1 Create the Models

# %%
# ==========================================
# Regression Models
# ==========================================
from sklearn.tree import DecisionTreeRegressor
models = {
    "Linear Regression": LinearRegression(),

    "Ridge Regression": Ridge(alpha=1.0),

    "Lasso Regression": Lasso(alpha=0.01),

    "Decision Tree": DecisionTreeRegressor(
        random_state=42
    ),

    "Random Forest": RandomForestRegressor(
        n_estimators=300,
        random_state=42
    ),

    "Gradient Boosting": GradientBoostingRegressor(
        random_state=42
    ),

    "Extra Trees": ExtraTreesRegressor(
        n_estimators=300,
        random_state=42
    ),

    "XGBoost": XGBRegressor(
        n_estimators=300,
        learning_rate=0.05,
        max_depth=5,
        random_state=42
    ),

    "LightGBM": LGBMRegressor(
        n_estimators=300,
        learning_rate=0.05,
        random_state=42,
        verbosity=-1
    )
}

# %%
print("NaN in df['Grade'] :", df["Grade"].isna().sum())
print("NaN in y          :", y.isna().sum())
print("NaN in y_train    :", y_train.isna().sum())

print("\nGrade values:")
print(df["Grade"].value_counts(dropna=False).sort_index())
# Out:
# NaN in df['Grade'] : 0
# NaN in y          : 0
# NaN in y_train    : 0
#
# Grade values:
# Grade
# 0     8
# 1    17
# 2    13
# 3    17
# 4    10
# 5    21
# 6    24
# 7    35
# Name: count, dtype: int64

# %% [markdown]
# ## 5.7.2 Train Every Model

# %%
# ==========================================
# Train All Models
# ==========================================

results = []

trained_models = {}

for name, model in models.items():

    pipeline = Pipeline([
        ("preprocessor", preprocessor),
        ("model", model)
    ])

    pipeline.fit(X_train, y_train)

    prediction = pipeline.predict(X_test)

    mae = mean_absolute_error(y_test, prediction)

    rmse = np.sqrt(mean_squared_error(y_test, prediction))

    r2 = r2_score(y_test, prediction)

    results.append({
        "Model": name,
        "MAE": round(mae, 3),
        "RMSE": round(rmse, 3),
        "R2": round(r2, 3)
    })

    trained_models[name] = pipeline

# %% [markdown]
# ## 5.7.3 Create the Results Table

# %%
results_df = pd.DataFrame(results)

results_df = results_df.sort_values(
    by="RMSE",
    ascending=True
)

results_df
# Out:
#                Model    MAE   RMSE     R2
# 2   Lasso Regression  1.710  2.152  0.083
# 1   Ridge Regression  1.698  2.184  0.056
# 0  Linear Regression  1.720  2.203  0.040
# 8           LightGBM  1.739  2.294 -0.041
# 5  Gradient Boosting  1.923  2.446 -0.183
# 4      Random Forest  2.020  2.512 -0.249
# 7            XGBoost  1.974  2.580 -0.317
# 3      Decision Tree  2.276  3.184 -1.006
# 6        Extra Trees  2.392  3.254 -1.096

# %% [markdown]
# ## 5.7.4 Visualize Model Performance

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Sort by RMSE (best at top)
results_df = results_df.sort_values("RMSE")

plt.figure(figsize=(10, 5))

sns.barplot(
    data=results_df,
    x="RMSE",
    y="Model",
    hue="Model",          # Seaborn 0.13 compatible
    palette="viridis",
    legend=False
)

plt.title("Model Comparison (Lower RMSE is Better)")
plt.xlabel("RMSE")
plt.ylabel("Model")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 5.7.5 Select the Best Model

# %%
best_model_name = results_df.iloc[0]["Model"]

best_model = trained_models[best_model_name]

print("Best Model:", best_model_name)
# Out:
# Best Model: Lasso Regression

# %% [markdown]
# ## 5.7.6 Save the Best Model

# %%
joblib.dump(
    best_model,
    "../models/best_model.pkl"
)
# Out:
# ['../models/best_model.pkl']

# %% [markdown]
# # Model Training Summary
#
# Nine regression models were trained using the same preprocessing pipeline.
#
# Evaluation metrics:
#
# - MAE
# - RMSE
# - R² Score
#
# The model with the lowest RMSE was selected as the production model and saved using Joblib.
